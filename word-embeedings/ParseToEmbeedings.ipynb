# %%
using Lazy
using DataFrames
using Memoize
push!(LOAD_PATH, "./TSne.jl/src/")
using Gadfly
using TSne

# %%
function load_embeddings(embedding_file="embeddings-scaled.EMBEDDING_SIZE=50.txt")
    embeddings = Dict{String,Vector{Float64}}()
    sizehint!(embeddings, 268810)
    for line in eachline(open(embedding_file))
        fields = line |> split
        word = fields[1]
        vec = map(parsefloat, fields[2:end])
        embeddings[word] = vec
    end
    embeddings
end
# Out:
# load_embeddings (generic function with 2 methods)

# %%
type WordEmbeddingResolver
    word2vec::Dict{String,Vector{Float64}}
    oov_vec::Vector{Float64} 
    
end


function WordEmbeddingResolver(embedding_file="embeddings-scaled.EMBEDDING_SIZE=50.txt", oov_word="*UNKNOWN*")
    word2vec = load_embeddings(embedding_file)
    oov_vec = pop!(word2vec, oov_word)
    print(oov_vec)
    WordEmbeddingResolver(word2vec, oov_vec)
end

@doc """Returns the vector embeeding for the wordkey. If not found returns the oov_vec""" ->
function getindex(resolver::WordEmbeddingResolver, word::String)
    get(resolver.word2vec, word, resolver.oov_vec) ::Vector{Float64}
end

function hasword(resolver::WordEmbeddingResolver, word::String)
    haskey(resolver.word2vec, word)
end

@memoize function vocab_words(resolver::WordEmbeddingResolver)
    Set(keys(resolver.word2vec))
end

# %%
embeddings =  WordEmbeddingResolver();
using HDF5, JLD
@save "embeddings_50.jld" embeddings
#load "embeddings_50.jld"
# Out:
# [0.
# 0398781252434,0.048215044877,0.0176077427638,-0.0251486353356,-0.0627525391573,0.025162565373,0.0117941274751,0.06136177709,0.018282828886,0.0289890409378,0.0305114695273,-0.0174257424723,0.0267882660686,-0.0147157088929,-0.00180382572305,-0.0240110330944,0.0348314405236,0.0331470930104,-0.072770576263,-0.0168486166738,-0.0239016486614,-0.0129813224306,-0.0289427776461,-0.0087953471783,-0.00791740590907,0.067884451273,-0.00875883697995,-0.00378532326298,-0.0147556102437,-0.0290714884049,-0.00577404736729,0.00911313898167,-0.0117291610829,-0.0562154301399,-0.0797217562057,-0.00686779437354,0.030256762279,0.00549994945996,-0.00159508308038,-0.0682754357922,-0.0136058665581,-0.0243803014322,-0.0181979406072,0.00254263276224,-0.0295248721186,-0.0390803609727,-0.0137563336122,0.0252651578644,0.0304082419565,0.0337323822856]

# %%
[embeddings["king"]-embeddings["male"]  embeddings["queen"]-embeddings["female"] embeddings["monarch"] embeddings["figurehead"] embeddings["leader"]]
# Out:
# 50x5 Array{Float64,2}:
#  -0.204519   -0.302901    -0.0864185   -0.0932634   -0.332573
#  -0.0591186   0.0266027    0.141159     0.121772     0.322254
#   0.0810681  -0.00771019  -0.00578134   0.0109424   -0.186722
#   0.0116136   0.0574605   -0.0227115    0.102123     0.27307
#  -0.332317   -0.502452     0.217831     0.0799675    0.229124
#   0.425591    0.367556    -0.0308615   -0.090607    -0.0679499
#  -0.0855455  -0.117584    -0.22731     -0.172909    -0.408299
#  -0.065921   -0.114593    -0.258328    -0.228152    -0.852001
#   0.237232    0.3241      -0.113373    -0.0891199    0.263852
#  -0.152355   -0.241289    -0.05275     -0.157367    -0.2825
#   0.0437036   0.291512     0.0896441   -0.20752     -0.125517
#  -0.101409   -0.183545     0.234045     0.0710295    0.0688362
#  -0.410698   -0.100165    -0.303875    -0.215935    -0.220256
#   ⋮
#   0.397843   -0.059257     0.0427803    0.222019     0.360823
#   0.133407   -0.14188      0.503633     0.0881525    0.326749
#  -0.0374784   0.125981    -0.150831     0.00730992  -0.323443
#  -0.393114   -0.193992    -0.12667      0.00900349  -0.69279
#   0.160976   -0.387926     0.130272    -0.216881     0.307907
#  -0.137803    0.145168     0.0983638    0.00116208  -0.0882417
#  -0.438935    0.0362962    0.028394    -0.269464     0.679969
#   0.240365    0.0924668    0.160692     0.10861     -0.0808747
#   0.140025   -0.00292672  -0.117291    -0.0378223   -0.0206875
#   0.554651    0.193125    -0.276407    -0.0490169   -0.00843159
#   0.270257    0.194269    -0.0276873   -0.170623     0.00646139
#  -0.35107    -0.17002     -0.400916    -0.345477    -0.60354

# %%
function csl2set(comma_seperated_list::String)
    @> comma_seperated_list split(",") Set
end

function csl2set(::NAtype)
    NA
end
    

function load_con_data(name)
    con = readtable("con_data/$name.csv")
    con[:tags] = map(csl2set,con[:tags])
    con[:people] = map(csl2set,con[:people])
    con
end
# Out:
# load_con_data (generic function with 1 method)

# %%
con = [load_con_data("swancon_2009");
    load_con_data("swancon_2010");
    load_con_data("swancon_2012");
    load_con_data("swancon_2013");
    load_con_data("swancon_2014");]
# Out:
# 979x8 DataFrames.DataFrame
# | Row | id    | start_time                        |
# |-----|-------|-----------------------------------|
# | 1   | 1533  | "Thu, 09 Apr 2009 08:30:00 -0400" |
# | 2   | 1534  | "Thu, 09 Apr 2009 08:30:00 -0400" |
# | 3   | 1535  | "Thu, 09 Apr 2009 09:30:00 -0400" |
# | 4   | 1536  | "Thu, 09 Apr 2009 04:00:00 -0400" |
# | 5   | 1537  | "Thu, 09 Apr 2009 09:30:00 -0400" |
# | 6   | 1538  | "Thu, 09 Apr 2009 08:30:00 -0400" |
# | 7   | 1539  | "Thu, 09 Apr 2009 09:30:00 -0400" |
# | 8   | 1540  | "Thu, 09 Apr 2009 10:30:00 -0400" |
# | 9   | 1541  | "Thu, 09 Apr 2009 09:30:00 -0400" |
# | 10  | 1542  | "Thu, 09 Apr 2009 08:30:00 -0400" |
# | 11  | 1543  | "Thu, 09 Apr 2009 10:30:00 -0400" |
# ⋮
# | 968 | 11754 | "Fri, 18 Apr 2014 02:30:00 -0400" |
# | 969 | 11755 | "Sat, 19 Apr 2014 04:00:00 -0400" |
# | 970 | 11756 | "Sat, 19 Apr 2014 23:00:00 -0400" |
# | 971 | 11757 | "Sat, 19 Apr 2014 23:30:00 -0400" |
# | 972 | 11758 | "Sun, 20 Apr 2014 01:00:00 -0400" |
# | 973 | 11759 | "Sun, 20 Apr 2014 03:00:00 -0400" |
# | 974 | 11760 | "Sun, 20 Apr 2014 03:30:00 -0400" |
# | 975 | 11761 | "Sun, 20 Apr 2014 22:00:00 -0400" |
# | 976 | 11762 | "Mon, 21 Apr 2014 00:30:00 -0400" |
# | 977 | 11763 | "Mon, 21 Apr 2014 02:30:00 -0400" |
# | 978 | 11764 | "Mon, 21 Apr 2014 04:00:00 -0400" |
# | 979 | 11942 | "Sun, 20 Apr 2014 02:30:00 -0400" |
#
# | Row | end_time                          |
# |-----|-----------------------------------|
# | 1   | "Thu, 09 Apr 2009 09:30:00 -0400" |
# | 2   | "Thu, 09 Apr 2009 09:30:00 -0400" |
# | 3   | "Thu, 09 Apr 2009 12:30:00 -0400" |
# | 4   | "Thu, 09 Apr 2009 05:00:00 -0400" |
# | 5   | "Thu, 09 Apr 2009 10:30:00 -0400" |
# | 6   | "Thu, 09 Apr 2009 09:30:00 -0400" |
# | 7   | "Thu, 09 Apr 2009 10:30:00 -0400" |
# | 8   | "Thu, 09 Apr 2009 11:30:00 -0400" |
# | 9   | "Thu, 09 Apr 2009 10:30:00 -0400" |
# | 10  | "Thu, 09 Apr 2009 09:30:00 -0400" |
# | 11  | "Thu, 09 Apr 2009 11:30:00 -0400" |
# ⋮
# | 968 | "Fri, 18 Apr 2014 03:00:00 -0400" |
# | 969 | "Sat, 19 Apr 2014 05:00:00 -0400" |
# | 970 | "Sat, 19 Apr 2014 23:30:00 -0400" |
# | 971 | "Sun, 20 Apr 2014 00:00:00 -0400" |
# | 972 | "Sun, 20 Apr 2014 03:00:00 -0400" |
# | 973 | "Sun, 20 Apr 2014 03:30:00 -0400" |
# | 974 | "Sun, 20 Apr 2014 04:30:00 -0400" |
# | 975 | "Mon, 21 Apr 2014 00:00:00 -0400" |
# | 976 | "Mon, 21 Apr 2014 02:00:00 -0400" |
# | 977 | "Mon, 21 Apr 2014 04:00:00 -0400" |
# | 978 | "Mon, 21 Apr 2014 05:00:00 -0400" |
# | 979 | "Sun, 20 Apr 2014 03:30:00 -0400" |
#
# | Row | title                                                         |
# |-----|---------------------------------------------------------------|
# | 1   | "A Brief History of Time Travel"                              |
# | 2   | "Art Registration and Display"                                |
# | 3   | "Art Show Closed"                                             |
# | 4   | "Art Show setup"                                              |
# | 5   | "Choose your own apocalypse - how our society might collapse" |
# | 6   | "Computers in SF"                                             |
# | 7   | "Digital art"                                                 |
# | 8   | "First Contact"                                               |
# | 9   | "I Am The Night: A History of the Caped Crusader"             |
# | 10  | "Killer Game Kick-off"                                        |
# | 11  | "Lost"                                                        |
# ⋮
# | 968 | "Reading"                                                     |
# | 969 | "Geekling Sing-A-Long"                                        |
# | 970 | "Reading"                                                     |
# | 971 | "Chocolate Checkers"                                          |
# | 972 | "The Best of MLP + Colouring In"                              |
# | 973 | "Reading"                                                     |
# | 974 | "Kitkat Jenga"                                                |
# | 975 | "Movie 1"                                                     |
# | 976 | "Movie 2"                                                     |
# | 977 | "Movie 3"                                                     |
# | 978 | "Pack Up"                                                     |
# | 979 | "Children's Masquerade"                                       |
#
# | Row | tags                                                           |
# |-----|----------------------------------------------------------------|
# | 1   | Set(SubString{UTF8String}[" Science fiction","Science"])       |
# | 2   | Set(SubString{UTF8String}[""])                                 |
# | 3   | Set(SubString{UTF8String}["Bookmark"])                         |
# | 4   | Set(SubString{UTF8String}["Bookmark"])                         |
# | 5   | Set(SubString{UTF8String}["Science"])                          |
# | 6   | Set(SubString{UTF8String}[" Science fiction","Science"])       |
# | 7   | Set(SubString{UTF8String}["Equipment: AV"," General"])         |
# | 8   | Set(SubString{UTF8String}["Science fiction"])                  |
# | 9   | Set(SubString{UTF8String}[" TV","Comics"," Media"])            |
# | 10  | Set(SubString{UTF8String}["General"," Icebreaker"])            |
# | 11  | Set(SubString{UTF8String}[" Science fiction"," TV","Fantasy"]) |
# ⋮
# | 968 | Set(SubString{UTF8String}[""])                                 |
# | 969 | Set(SubString{UTF8String}[""])                                 |
# | 970 | Set(SubString{UTF8String}[""])                                 |
# | 971 | Set(SubString{UTF8String}[""])                                 |
# | 972 | Set(SubString{UTF8String}[""])                                 |
# | 973 | Set(SubString{UTF8String}[""])                                 |
# | 974 | Set(SubString{UTF8String}[""])                                 |
# | 975 | Set(SubString{UTF8String}[""])                                 |
# | 976 | Set(SubString{UTF8String}[""])                                 |
# | 977 | Set(SubString{UTF8String}[""])                                 |
# | 978 | Set(SubString{UTF8String}[""])                                 |
# | 979 | Set(SubString{UTF8String}[""])                                 |
#
# | Row | people                                                                                             |
# |-----|----------------------------------------------------------------------------------------------------|
# | 1   | Set(SubString{UTF8String}[" Kevin McCaw","Michael Cogan"])                                         |
# | 2   | Set(SubString{UTF8String}[""])                                                                     |
# | 3   | Set(SubString{UTF8String}[""])                                                                     |
# | 4   | Set(SubString{UTF8String}[""])                                                                     |
# | 5   | Set(SubString{UTF8String}[" Anna Hepworth"," Margaret Dunlop","Art Diggle"])                       |
# | 6   | Set(SubString{UTF8String}["Theresa Anns"," Rob Masters"," John Parker"])                           |
# | 7   | Set(SubString{UTF8String}[" Sarah Xu","Nancy Lorenz"," Emily Smith"," Andy Phillips"," Lisa Rye"]) |
# | 8   | Set(SubString{UTF8String}["Anna Hepworth"," Elaine Walker"])                                       |
# | 9   | Set(SubString{UTF8String}[" Zoe Wadsworth"," Damian Magee","Travis Johnson"," Grant Watson"])      |
# | 10  | Set(SubString{UTF8String}["Bill"])                                                                 |
# | 11  | Set(SubString{UTF8String}[" Sarah Xu"," Graeme Watson","Tom Eitelhuber"])                          |
# ⋮
# | 968 | Set(SubString{UTF8String}[""])                                                                     |
# | 969 | Set(SubString{UTF8String}["Desiree Heald"])                                                        |
# | 970 | Set(SubString{UTF8String}[""])                                                                     |
# | 971 | Set(SubString{UTF8String}[""])                                                                     |
# | 972 | Set(SubString{UTF8String}["Adam McCaw"])                                                           |
# | 973 | Set(SubString{UTF8String}[""])                                                                     |
# | 974 | Set(SubString{UTF8String}[""])                                                                     |
# | 975 | Set(SubString{UTF8String}[""])                                                                     |
# | 976 | Set(SubString{UTF8String}[""])                                                                     |
# | 977 | Set(SubString{UTF8String}[""])                                                                     |
# | 978 | Set(SubString{UTF8String}[""])                                                                     |
# | 979 | Set(SubString{UTF8String}["Emma Hawkes"])                                                          |
#
# | Row | venues             |
# |-----|--------------------|
# | 1   | "Montana A"        |
# | 2   | "Oshaneshii"       |
# | 3   | "Oshaneshii"       |
# | 4   | "Oshaneshii"       |
# | 5   | "Montana B"        |
# | 6   | "Cocktail Lounge"  |
# | 7   | "Cocktail Lounge"  |
# | 8   | "Montana B"        |
# | 9   | "Montana A"        |
# | 10  | "Other"            |
# | 11  | "Montana A"        |
# ⋮
# | 968 | "Family Room (L1)" |
# | 969 | "Family Room (L1)" |
# | 970 | "Family Room (L1)" |
# | 971 | "Family Room (L1)" |
# | 972 | "Family Room (L1)" |
# | 973 | "Family Room (L1)" |
# | 974 | "Family Room (L1)" |
# | 975 | "Family Room (L1)" |
# | 976 | "Family Room (L1)" |
# | 977 | "Family Room (L1)" |
# | 978 | "Family Room (L1)" |
# | 979 | "Family Room (L1)" |
#
# | Row | description                                                                                                                                                                                                                                                                                                                                                                                                      |
# |-----|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | 1   | "Who writes about it well? What are the theories? Why can't I kill my grandmother? What are the Trousers of Time? (diagrams required)"                                                                                                                                                                                                                                                                           |
# | 2   | ""                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 3   | ""                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 4   | ""                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 5   | "Societies can collapse in a number of different ways for different reasons.  Which ones are most likely to apply to us?  What sort of collapse might we be in for?"                                                                                                                                                                                                                                             |
# | 6   | "From Orac to HAL to Skynet, come and discuss the various visions of computers in SF. Past, present and whatever they may hold in the future."                                                                                                                                                                                                                                                                   |
# | 7   | "Holograms, online archives, mashups... how does it compare to traditional art practices? Discussion with examples."                                                                                                                                                                                                                                                                                             |
# | 8   | "From War of the Worlds to Carl Sagan's Contact and beyond: a discussion of first contact novels and movies."                                                                                                                                                                                                                                                                                                    |
# | 9   | "More than 70 years of comics, eight feature films, two movie serials, countless television shows - the Batman is one of the most iconic and effective pop culture heroes of the past century.\n\nWhy is the character so effective? What is the core appeal? Does Batman exist as a simple vigilante fantasy, or are there deeper themes at work? An examination of Batman in comics, in film and in television." |
# | 10  | "Subtly (or not) take out your competitors. This will be run adjacent to the regular programme and is designed not to interfere with the con itself.\n\nParticipate at your own risk!"                                                                                                                                                                                                                             |
# | 11  | "The TV series Lost is scheduled to conclude in 2010, with just over twenty episodes remaining. This definite time-limit suggests that The Survivors and Others are finally headed towards some sort of climactic endgame. This panel will encourage open discussion on the current and previous seasons, as well as speculation on future events."                                                              |
# ⋮
# | 968 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 969 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 970 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 971 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 972 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 973 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 974 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 975 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 976 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 977 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 978 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |
# | 979 | NA                                                                                                                                                                                                                                                                                                                                                                                                               |

# %%
@doc "Breaks up text, in to a list of words. It will split off the suffix and prefixes into seperate words if this causes the base word to be in the preffered words list" ->
function breakup_text(  text::String, 
    preferred_words::Set{String},
    suffixes = ["",",",";",".", "n't", "'s", "'ve", "!", "*", "...", "?", ":", ")", "\""],
    prefixes = ["","(", "\""])
    
    assert("" == suffixes[1])
    assert("" == prefixes[1])
    
    unpreferred_words = Array{String}(0)
    words = Array{String}(0)
    for field in split(text)
        found = false
        for pre in prefixes, suf in suffixes #The straight word is covered by the prefix and suffix ""
            if startswith(field,pre) && endswith(field,suf)
                word = field[1+length(pre):end-length(suf)]
                #println("***[$pre][$word][$suf]")
                if word in preferred_words
                    for part in [pre,word,suf]
                        if !isempty(part)
                            push!(words,part)
                        end
                    end
                    found = true
                    break
                end
            end
        end

        if !found #(ie else prefix loop not broken) so Not a prefferd word
            push!(words,field) #Put it on the word list anyway, it will be dealt with later
            push!(unpreferred_words,field) #but also note it as a problem
        end
        
    end
    words, unpreferred_words
end

function breakup_text(::DataArrays.NAtype, ::Set{AbstractString})
   NA, NA
end
# Out:
# breakup_text (generic function with 4 methods)

# %%
function get_total_embedding(embeddings::WordEmbeddingResolver, text::String)
    words::Vector{String}= breakup_text(text, vocab_words(embeddings))[1]
    if !isempty(words)
        @>>words map(ww->embeddings[ww]) sum    
    else
        NA
    end
    
end

function get_total_embedding(embeddings::WordEmbeddingResolver, text::NAtype)
    NA
end

con[:desc_vec] = @>> con[:description] map(desc->get_total_embedding(embeddings, desc));

# %%
cleanCon = con[!isna(con[:desc_vec]),:]
""

X = hcat(cleanCon[:desc_vec]...)'
labels = ones(size(X,2))
plotname = "iris"
initial_dims = -1
iterations = 1500
perplexity = 15

println("X dimensions are: $(size(X))")
Y = tsne(X, 2, initial_dims, iterations, perplexity)
println("Y dimensions are: $(size(Y))")
plot(x=Y[:,1], y=Y[:,2], color=labels)
# Out:
# X dimensions are: (715,50)
# Initial X Shape is : (715,50)
# Computing pairwise distances...
# WARNING: [a] concatenation is deprecated; use [a;] instead
# Computing P-values for point 500 of 715...
#  in depwarn at ./deprecated.jl:40
#  in oldstyle_vcat_warning at ./abstractarray.jl:26
#  in x2p at /home/wheel/oxinabox/programming/JuliaLearning/word-embeedings/TSne.jl/src/TSne.jl:33
#  in tsne at /home/wheel/oxinabox/programming/JuliaLearning/word-embeedings/TSne.jl/src/TSne.jl:117
#  in include_string at loading.jl:97
#  in execute_request_0x535c5df2 at /home/wheel/oxinabox/.julia/v0.4/IJulia/src/execute_request.jl:140
#  in eventloop at /home/wheel/oxinabox/.julia/v0.4/IJulia/src/IJulia.jl:123
#  in anonymous at task.jl:344
# Mean value of sigma: 5.418493079126217
# Iteration
# 10: error is -7.081761733835758e-6
# Iteration
# 20: error is -6.962306411809803e-6
# Iteration
# 30: error is -6.884048589217433e-6
# Iteration
# 40: error is -6.849288248842869e-6
# Iteration
# 50: error is -6.836103516200987e-6
# Iteration
# 60: error is -6.8297156490227965e-6
# Iteration
# 70: error is -6.826078457513712e-6
# Iteration
# 80: error is -6.8237966881493e-6
# Iteration
# 90: error is -6.822264455080359e-6
# Iteration
# 100: error is -6.821195187217158e-6
# Iteration
# 110: error is -1.8822818873801452e-6
# Iteration
# 120: error is -1.8821353337308858e-6
# Iteration
# 130: error is -1.882021290958703e-6
# Iteration
# 140: error is -1.8819311266460767e-6
# Iteration
# 150: error is -1.8818587953286643e-6
# Iteration
# 160: error is -1.8817996862761015e-6
# Iteration
# 170: error is -1.881750791632326e-6
# Iteration
# 180: error is -1.881710026206242e-6
# Iteration
# 190: error is -1.8816757878171817e-6
# Iteration
# 200: error is -1.8816468178051194e-6
# Iteration
# 210: error is -1.8816221117324768e-6
# Iteration
# 220: error is -1.881600865776346e-6
# Iteration
# 230: error is -1.8815824478363644e-6
# Iteration
# 240: error is -1.8815663694446357e-6
# Iteration
# 250: error is -1.8815522508503704e-6
# Iteration
# 260: error is -1.8815397860618002e-6
# Iteration
# 270: error is -1.8815287178652056e-6
# Iteration
# 280: error is -1.881518827542664e-6
# Iteration
# 290: error is -1.881509934956828e-6
# Iteration
# 300: error is -1.8815018987933971e-6
# Iteration
# 310: error is -1.8814946104805343e-6
# Iteration
# 320: error is -1.8814879840994884e-6
# Iteration
# 330: error is -1.8814819478102543e-6
# Iteration
# 340: error is -1.8814764390323963e-6
# Iteration
# 350: error is -1.8814714023639814e-6
# Iteration
# 360: error is -1.8814667886827745e-6
# Iteration
# 370: error is -1.881462554570526e-6
# Iteration
# 380: error is -1.881458661777851e-6
# Iteration
# 390: error is -1.8814550766823958e-6
# Iteration
# 400: error is -1.8814517697520792e-6
# Iteration
# 410: error is -1.881448715031406e-6
# Iteration
# 420: error is -1.8814458896650937e-6
# Iteration
# 430: error is -1.8814432734682958e-6
# Iteration
# 440: error is -1.881440848547663e-6
# Iteration
# 450: error is -1.8814385989730898e-6
# Iteration
# 460: error is -1.881436510496917e-6
# Iteration
# 470: error is -1.8814345703157647e-6
# Iteration
# 480: error is -1.8814327668697471e-6
# Iteration
# 490: error is -1.8814310896740363e-6
# Iteration
# 500: error is -1.881429529178242e-6
# Iteration
# 510: error is -1.881428076649527e-6
# Iteration
# 520: error is -1.8814267240757794e-6
# Iteration
# 530: error is -1.8814254640854812e-6
# Iteration
# 540: error is -1.8814242898812277e-6
# Iteration
# 550: error is -1.881423195184234e-6
# Iteration
# 560: error is -1.881422174187583e-6
# Iteration
# 570: error is -1.8814212215164577e-6
# Iteration
# 580: error is -1.881420332194048e-6
# Iteration
# 590: error is -1.8814195016121838e-6
# Iteration
# 600: error is -1.8814187255059753e-6
# Iteration
# 610: error is -1.8814179999318034e-6
# Iteration
# 620: error is -1.8814173212479195e-6
# Iteration
# 630: error is -1.8814166860967706e-6
# Iteration
# 640: error is -1.8814160913880172e-6
# Iteration
# 650: error is -1.8814155342811547e-6
# Iteration
# 660: error is -1.8814150121667756e-6
# Iteration
# 670: error is -1.881414522645813e-6
# Iteration
# 680: error is -1.8814140635065934e-6
# Iteration
# 690: error is -1.8814136327001145e-6
# Iteration
# 700: error is -1.8814132283145374e-6
# Iteration
# 710: error is -1.8814128485503625e-6
# Iteration
# 720: error is -1.881412491697981e-6
# Iteration
# 730: error is -1.8814121561192853e-6
# Iteration
# 740: error is -1.8814118402346826e-6
# Iteration
# 750: error is -1.8814115425163166e-6
# Iteration
# 760: error is -1.8814112614875797e-6
# Iteration
# 770: error is -1.8814109957282748e-6
# Iteration
# 780: error is -1.881410743884108e-6
# Iteration
# 790: error is -1.8814105046787534e-6
# Iteration
# 800: error is -1.881410276926507e-6
# Iteration
# 810: error is -1.8814100595436476e-6
# Iteration
# 820: error is -1.8814098515569446e-6
# Iteration
# 830: error is -1.8814096521082728e-6
# Iteration
# 840: error is -1.881409460454887e-6
# Iteration
# 850: error is -1.88140927596548e-6
# Iteration
# 860: error is -1.8814090981126061e-6
# Iteration
# 870: error is -1.8814089264623655e-6
# Iteration
# 880: error is -1.8814087606623602e-6
# Iteration
# 890: error is -1.88140860042893e-6
# Iteration
# 900: error is -1.881408445534527e-6
# Iteration
# 910: error is -1.8814082957958963e-6
# Iteration
# 920: error is -1.8814081510635153e-6
# Iteration
# 930: error is -1.8814080112125274e-6
# Iteration
# 940: error is -1.8814078761352475e-6
# Iteration
# 950: error is -1.8814077457351858e-6
# Iteration
# 960: error is -1.8814076199224478e-6
# Iteration
# 970: error is -1.8814074986103376e-6
# Iteration
# 980: error is -1.881407381712955e-6
# Iteration
# 990: error is -1.8814072691436027e-6
# Iteration
# 1000: error is -1.8814071608138212e-6
# Iteration
# 1010: error is -1.8814070566328993e-6
# Iteration
# 1020: error is -1.8814069565077295e-6
# Iteration
# 1030: error is -1.8814068603429099e-6
# Iteration
# 1040: error is -1.8814067680410064e-6
# Iteration
# 1050: error is -1.881406679502915e-6
# Iteration
# 1060: error is -1.8814065946282798e-6
# Iteration
# 1070: error is -1.8814065133159288e-6
# Iteration
# 1080: error is -1.8814064354643088e-6
# Iteration
# 1090: error is -1.8814063609719003e-6
# Iteration
# 1100: error is -1.8814062897376066e-6
# Iteration
# 1110: error is -1.8814062216611036e-6
# Iteration
# 1120: error is -1.8814061566431572e-6
# Iteration
# 1130: error is -1.8814060945859003e-6
# Iteration
# 1140: error is -1.8814060353930738e-6
# Iteration
# 1150: error is -1.8814059789702324e-6
# Iteration
# 1160: error is -1.8814059252249176e-6
# Iteration
# 1170: error is -1.8814058740668015e-6
# Iteration
# 1180: error is -1.881405825407802e-6
# Iteration
# 1190: error is -1.881405779162173e-6
# Iteration
# 1200: error is -1.8814057352465758e-6
# Iteration
# 1210: error is -1.8814056935801275e-6
# Iteration
# 1220: error is -1.8814056540844349e-6
# Iteration
# 1230: error is -1.8814056166836119e-6
# Iteration
# 1240: error is -1.8814055813042844e-6
# Iteration
# 1250: error is -1.8814055478755862e-6
# Iteration
# 1260: error is -1.881405516329141e-6
# Iteration
# 1270: error is -1.8814054865990392e-6
# Iteration
# 1280: error is -1.8814054586218088e-6
# Iteration
# 1290: error is -1.8814054323363768e-6
# Iteration
# 1300: error is -1.8814054076840294e-6
# Iteration
# 1310: error is -1.881405384608365e-6
# Iteration
# 1320: error is -1.8814053630552477e-6
# Iteration
# 1330: error is -1.8814053429727544e-6
# Iteration
# 1340: error is -1.881405324311123e-6
# Iteration
# 1350: error is -1.881405307022696e-6
# Iteration
# 1360: error is -1.8814052910618672e-6
# Iteration
# 1370: error is -1.8814052763850235e-6
# Iteration
# 1380: error is -1.8814052629504882e-6
# Iteration
# 1390: error is -1.881405250718466e-6
# Iteration
# 1400: error is -1.8814052396509842e-6
# Iteration
# 1410: error is -1.8814052297118377e-6
# Iteration
# 1420: error is -1.8814052208665331e-6
# Iteration
# 1430: error is -1.8814052130822336e-6
# Iteration
# 1440: error is -1.8814052063277047e-6
# Iteration
# 1450: error is -1.881405200573261e-6
# Iteration
# 1460: error is -1.8814051957907144e-6
# Iteration
# 1470: error is -1.8814051919533224e-6
# Iteration
# 1480: error is -1.8814051890357386e-6
# Iteration
# 1490: error is -1.8814051870139635e-6
# Iteration
# 1500: error is -1.8814051858652975e-6
# Y dimensions are: (715,2)
# Vector form and vector property differ in length. Can't distribute.
#
#  in print_vector_properties at /home/wheel/oxinabox/.julia/v0.4/Compose/src/svg.jl:723
#  in draw at /home/wheel/oxinabox/.julia/v0.4/Compose/src/svg.jl:787
#  in draw at /home/wheel/oxinabox/.julia/v0.4/Compose/src/svg.jl:738
#  in draw at /home/wheel/oxinabox/.julia/v0.4/Compose/src/form.jl:23
#  in drawpart at /home/wheel/oxinabox/.julia/v0.4/Compose/src/container.jl:510
#  in draw at /home/wheel/oxinabox/.julia/v0.4/Compose/src/container.jl:400
#  in writemime at /home/wheel/oxinabox/.julia/v0.4/Gadfly/src/Gadfly.jl:884
#  in sprint at iostream.jl:229
#  in display_dict at /home/wheel/oxinabox/.julia/v0.4/IJulia/src/execute_request.jl:31

# %%
using Compose
X = hcat(cleanCon[:desc_vec]...)
labels = ones(size(X,2))

plot(x=Y[:,1], y=Y[:,2], color=labels,
    Guide.annotation(
compose(context(), circle([pi/2, 3*pi/2], [1.0, -1.0], [2mm]))))
# Out:
# Plot(...)

# %%
labels = cleanCon[:venues]

plot(x=Y[:,1], y=Y[:,2], color=labels,)
# Out:
# Plot(...)
