# %%
using Lazy
using DataFrames
using Memoize
# Out:
# WARNING: deprecated syntax "{}" at /home/wheel/oxinabox/.julia/v0.4/Memoize/src/Memoize.jl:24.
# Use "[]" instead.

# %%
function load_embeddings(embedding_file="embeddings-scaled.EMBEDDING_SIZE=50.txt")
    embeddings = Dict{String,Vector{Float64}}()
    sizehint!(embeddings, 268810)
    for line in eachline(open(embedding_file))
        fields = line |> split
        word = fields[1]
        vec = map(parsefloat, fields[2:end])
        embeddings[word] = vec
    end
    embeddings
end
# Out:
# load_embeddings (generic function with 2 methods)

# %%
type WordEmbeddingResolver
    word2vec::Dict{String,Vector{Float64}}
    oov_vec::Vector{Float64} 
    
end


function WordEmbeddingResolver(embedding_file="embeddings-scaled.EMBEDDING_SIZE=50.txt", oov_word="*UNKNOWN*")
    word2vec = load_embeddings(embedding_file)
    oov_vec = pop!(word2vec, oov_word)
    print(oov_vec)
    WordEmbeddingResolver(word2vec, oov_vec)
end

@doc """Returns the vector embeeding for the wordkey. If not found returns the oov_vec""" ->
function getindex(resolver::WordEmbeddingResolver, word::String)
    get(resolver.word2vec, word, resolver.oov_vec)
end

function hasword(resolver::WordEmbeddingResolver, word::String)
    haskey(resolver.word2vec, word)
end

@memoize function vocab_words(resolver::WordEmbeddingResolver)
    Set(keys(resolver.word2vec))
end

# %%
embeddings =  WordEmbeddingResolver();
using HDF5, JLD
@save "embeddings_50.jld" embeddings
#load "embeddings_50.jld"
# Out:
# [0.
# 0398781252434,0.048215044877,0.0176077427638,-0.0251486353356,-0.0627525391573,0.025162565373,0.0117941274751,0.06136177709,0.018282828886,0.0289890409378,0.0305114695273,-0.0174257424723,0.0267882660686,-0.0147157088929,-0.00180382572305,-0.0240110330944,0.0348314405236,0.0331470930104,-0.072770576263,-0.0168486166738,-0.0239016486614,-0.0129813224306,-0.0289427776461,-0.0087953471783,-0.00791740590907,0.067884451273,-0.00875883697995,-0.00378532326298,-0.0147556102437,-0.0290714884049,-0.00577404736729,0.00911313898167,-0.0117291610829,-0.0562154301399,-0.0797217562057,-0.00686779437354,0.030256762279,0.00549994945996,-0.00159508308038,-0.0682754357922,-0.0136058665581,-0.0243803014322,-0.0181979406072,0.00254263276224,-0.0295248721186,-0.0390803609727,-0.0137563336122,0.0252651578644,0.0304082419565,0.0337323822856]

# %%
[embeddings["king"]-embeddings["male"]  embeddings["queen"]-embeddings["female"] embeddings["monarch"] embeddings["figurehead"] embeddings["leader"]]
# Out:
# 50x5 Array{Float64,2}:
#  -0.204519   -0.302901    -0.0864185   -0.0932634   -0.332573
#  -0.0591186   0.0266027    0.141159     0.121772     0.322254
#   0.0810681  -0.00771019  -0.00578134   0.0109424   -0.186722
#   0.0116136   0.0574605   -0.0227115    0.102123     0.27307
#  -0.332317   -0.502452     0.217831     0.0799675    0.229124
#   0.425591    0.367556    -0.0308615   -0.090607    -0.0679499
#  -0.0855455  -0.117584    -0.22731     -0.172909    -0.408299
#  -0.065921   -0.114593    -0.258328    -0.228152    -0.852001
#   0.237232    0.3241      -0.113373    -0.0891199    0.263852
#  -0.152355   -0.241289    -0.05275     -0.157367    -0.2825
#   0.0437036   0.291512     0.0896441   -0.20752     -0.125517
#  -0.101409   -0.183545     0.234045     0.0710295    0.0688362
#  -0.410698   -0.100165    -0.303875    -0.215935    -0.220256
#   ⋮
#   0.397843   -0.059257     0.0427803    0.222019     0.360823
#   0.133407   -0.14188      0.503633     0.0881525    0.326749
#  -0.0374784   0.125981    -0.150831     0.00730992  -0.323443
#  -0.393114   -0.193992    -0.12667      0.00900349  -0.69279
#   0.160976   -0.387926     0.130272    -0.216881     0.307907
#  -0.137803    0.145168     0.0983638    0.00116208  -0.0882417
#  -0.438935    0.0362962    0.028394    -0.269464     0.679969
#   0.240365    0.0924668    0.160692     0.10861     -0.0808747
#   0.140025   -0.00292672  -0.117291    -0.0378223   -0.0206875
#   0.554651    0.193125    -0.276407    -0.0490169   -0.00843159
#   0.270257    0.194269    -0.0276873   -0.170623     0.00646139
#  -0.35107    -0.17002     -0.400916    -0.345477    -0.60354

# %%
function csl2set(comma_seperated_list)
    @> comma_seperated_list split(",") Set
end

function load_con_data(name)
    con = readtable("con_data/$name.csv")
    con[:tags] = map(csl2set,con[:tags])
    con[:people] = map(csl2set,con[:people])
    con
end
# Out:
# load_con_data (generic function with 1 method)

# %%
con = load_con_data("swancon_2014")
# Out:
# 215x8 DataFrames.DataFrame
# | Row | id    | start_time                        |
# |-----|-------|-----------------------------------|
# | 1   | 10684 | "Sat, 19 Apr 2014 03:30:00 -0400" |
# | 2   | 10685 | "Fri, 18 Apr 2014 03:30:00 -0400" |
# | 3   | 10686 | "Thu, 17 Apr 2014 22:30:00 -0400" |
# | 4   | 10687 | "Thu, 17 Apr 2014 09:00:00 -0400" |
# | 5   | 10689 | "Thu, 17 Apr 2014 23:30:00 -0400" |
# | 6   | 10693 | "Fri, 18 Apr 2014 01:30:00 -0400" |
# | 7   | 10694 | "Fri, 18 Apr 2014 05:30:00 -0400" |
# | 8   | 10695 | "Thu, 17 Apr 2014 22:30:00 -0400" |
# | 9   | 10696 | "Fri, 18 Apr 2014 04:30:00 -0400" |
# | 10  | 10697 | "Fri, 18 Apr 2014 08:00:00 -0400" |
# | 11  | 10698 | "Fri, 18 Apr 2014 09:00:00 -0400" |
# ⋮
# | 204 | 11754 | "Fri, 18 Apr 2014 02:30:00 -0400" |
# | 205 | 11755 | "Sat, 19 Apr 2014 04:00:00 -0400" |
# | 206 | 11756 | "Sat, 19 Apr 2014 23:00:00 -0400" |
# | 207 | 11757 | "Sat, 19 Apr 2014 23:30:00 -0400" |
# | 208 | 11758 | "Sun, 20 Apr 2014 01:00:00 -0400" |
# | 209 | 11759 | "Sun, 20 Apr 2014 03:00:00 -0400" |
# | 210 | 11760 | "Sun, 20 Apr 2014 03:30:00 -0400" |
# | 211 | 11761 | "Sun, 20 Apr 2014 22:00:00 -0400" |
# | 212 | 11762 | "Mon, 21 Apr 2014 00:30:00 -0400" |
# | 213 | 11763 | "Mon, 21 Apr 2014 02:30:00 -0400" |
# | 214 | 11764 | "Mon, 21 Apr 2014 04:00:00 -0400" |
# | 215 | 11942 | "Sun, 20 Apr 2014 02:30:00 -0400" |
#
# | Row | end_time                          |
# |-----|-----------------------------------|
# | 1   | "Sat, 19 Apr 2014 04:30:00 -0400" |
# | 2   | "Fri, 18 Apr 2014 04:30:00 -0400" |
# | 3   | "Thu, 17 Apr 2014 23:30:00 -0400" |
# | 4   | "Thu, 17 Apr 2014 10:00:00 -0400" |
# | 5   | "Fri, 18 Apr 2014 00:30:00 -0400" |
# | 6   | "Fri, 18 Apr 2014 02:30:00 -0400" |
# | 7   | "Fri, 18 Apr 2014 06:30:00 -0400" |
# | 8   | "Thu, 17 Apr 2014 23:30:00 -0400" |
# | 9   | "Fri, 18 Apr 2014 05:30:00 -0400" |
# | 10  | "Fri, 18 Apr 2014 09:00:00 -0400" |
# | 11  | "Fri, 18 Apr 2014 10:00:00 -0400" |
# ⋮
# | 204 | "Fri, 18 Apr 2014 03:00:00 -0400" |
# | 205 | "Sat, 19 Apr 2014 05:00:00 -0400" |
# | 206 | "Sat, 19 Apr 2014 23:30:00 -0400" |
# | 207 | "Sun, 20 Apr 2014 00:00:00 -0400" |
# | 208 | "Sun, 20 Apr 2014 03:00:00 -0400" |
# | 209 | "Sun, 20 Apr 2014 03:30:00 -0400" |
# | 210 | "Sun, 20 Apr 2014 04:30:00 -0400" |
# | 211 | "Mon, 21 Apr 2014 00:00:00 -0400" |
# | 212 | "Mon, 21 Apr 2014 02:00:00 -0400" |
# | 213 | "Mon, 21 Apr 2014 04:00:00 -0400" |
# | 214 | "Mon, 21 Apr 2014 05:00:00 -0400" |
# | 215 | "Sun, 20 Apr 2014 03:30:00 -0400" |
#
# | Row | title                                                           |
# |-----|-----------------------------------------------------------------|
# | 1   | "Homestuck: The Phenomenon"                                     |
# | 2   | "Crucial moments in Classic Dr Who"                             |
# | 3   | "Writing Overtly Feminist Books In A Non Feminist World"        |
# | 4   | "Good Eats: The Geekiest Cooking Show On Earth"                 |
# | 5   | "The Good Die Young:Short Lived Series"                         |
# | 6   | "Where All the Cool Kids Are: On the Rise of Indie Videogaming" |
# | 7   | "Person of Interest"                                            |
# | 8   | "Wham! Pow! Hug!: Our Favourite Comics"                         |
# | 9   | "Rise of the Mutants: The X-Men under Chris Claremont"          |
# | 10  | "Genre Themes in Non Genre Shows"                               |
# | 11  | "Fangirling About Non-Genre Shows"                              |
# ⋮
# | 204 | "Reading"                                                       |
# | 205 | "Geekling Sing-A-Long"                                          |
# | 206 | "Reading"                                                       |
# | 207 | "Chocolate Checkers"                                            |
# | 208 | "The Best of MLP + Colouring In"                                |
# | 209 | "Reading"                                                       |
# | 210 | "Kitkat Jenga"                                                  |
# | 211 | "Movie 1"                                                       |
# | 212 | "Movie 2"                                                       |
# | 213 | "Movie 3"                                                       |
# | 214 | "Pack Up"                                                       |
# | 215 | "Children's Masquerade"                                         |
#
# | Row | tags                                                                             |
# |-----|----------------------------------------------------------------------------------|
# | 1   | Set(SubString{UTF8String}[" Web Comics","Fandom"])                               |
# | 2   | Set(SubString{UTF8String}["Dr Who"])                                             |
# | 3   | Set(SubString{UTF8String}[" Social Justice","Craft of Writing"," Needs People"]) |
# | 4   | Set(SubString{UTF8String}["Food"," TV"])                                         |
# | 5   | Set(SubString{UTF8String}["TV"," TV"])                                           |
# | 6   | Set(SubString{UTF8String}["Video Games"])                                        |
# | 7   | Set(SubString{UTF8String}["Non-Genre"," TV"])                                    |
# | 8   | Set(SubString{UTF8String}["Comics"])                                             |
# | 9   | Set(SubString{UTF8String}["Comics"])                                             |
# | 10  | Set(SubString{UTF8String}[" TV"," Non-Genre","Needs People"])                    |
# | 11  | Set(SubString{UTF8String}[" TV"," Non-Genre","Fandom"])                          |
# ⋮
# | 204 | Set(SubString{UTF8String}[""])                                                   |
# | 205 | Set(SubString{UTF8String}[""])                                                   |
# | 206 | Set(SubString{UTF8String}[""])                                                   |
# | 207 | Set(SubString{UTF8String}[""])                                                   |
# | 208 | Set(SubString{UTF8String}[""])                                                   |
# | 209 | Set(SubString{UTF8String}[""])                                                   |
# | 210 | Set(SubString{UTF8String}[""])                                                   |
# | 211 | Set(SubString{UTF8String}[""])                                                   |
# | 212 | Set(SubString{UTF8String}[""])                                                   |
# | 213 | Set(SubString{UTF8String}[""])                                                   |
# | 214 | Set(SubString{UTF8String}[""])                                                   |
# | 215 | Set(SubString{UTF8String}[""])                                                   |
#
# | Row | people                                                                                       |
# |-----|----------------------------------------------------------------------------------------------|
# | 1   | Set(SubString{UTF8String}["Alexis Hemsley"," Cathy Rye"," Sophie McFarland"," Paul Wright"]) |
# | 2   | Set(SubString{UTF8String}["Damian Magee"," Heather Magee"," David Medlen"])                  |
# | 3   | Set(SubString{UTF8String}[" Gina Goddard","Isobelle Carmody"])                               |
# | 4   | Set(SubString{UTF8String}[" John Parker"," Shay Telfer","Bec Handcock"])                     |
# | 5   | Set(SubString{UTF8String}[" David Gunn","Belinda Forbes"," Kat Griffiths"])                  |
# | 6   | Set(SubString{UTF8String}[" Wendy White"," Brendan Ragan","Paul Chamberlain"," Lisa Rye"])   |
# | 7   | Set(SubString{UTF8String}["PRK "," Sarah McFarlane"," Sven Lie"])                            |
# | 8   | Set(SubString{UTF8String}[" Candice Schilder"," Krisjan Lie","Jon Hayward"])                 |
# | 9   | Set(SubString{UTF8String}[" Kitty Hemsley"," John Parker","Royd "])                          |
# | 10  | Set(SubString{UTF8String}["Kitty Hemsley"," Sarah McFarlane"])                               |
# | 11  | Set(SubString{UTF8String}["Denai Edwards"," Katherine McFarlane"," Ruth Turner"])            |
# ⋮
# | 204 | Set(SubString{UTF8String}[""])                                                               |
# | 205 | Set(SubString{UTF8String}["Desiree Heald"])                                                  |
# | 206 | Set(SubString{UTF8String}[""])                                                               |
# | 207 | Set(SubString{UTF8String}[""])                                                               |
# | 208 | Set(SubString{UTF8String}["Adam McCaw"])                                                     |
# | 209 | Set(SubString{UTF8String}[""])                                                               |
# | 210 | Set(SubString{UTF8String}[""])                                                               |
# | 211 | Set(SubString{UTF8String}[""])                                                               |
# | 212 | Set(SubString{UTF8String}[""])                                                               |
# | 213 | Set(SubString{UTF8String}[""])                                                               |
# | 214 | Set(SubString{UTF8String}[""])                                                               |
# | 215 | Set(SubString{UTF8String}["Emma Hawkes"])                                                    |
#
# | Row | venues                |
# |-----|-----------------------|
# | 1   | "Champagne A (G)"     |
# | 2   | "Champagne B (G)"     |
# | 3   | "Provence (L2)"       |
# | 4   | "Champagne B (G)"     |
# | 5   | "Bordeaux North (L1)" |
# | 6   | "Bordeaux North (L1)" |
# | 7   | "Champagne B (G)"     |
# | 8   | "Champagne B (G)"     |
# | 9   | "Champagne B (G)"     |
# | 10  | "Bordeaux North (L1)" |
# | 11  | "Bordeaux North (L1)" |
# ⋮
# | 204 | "Family Room (L1)"    |
# | 205 | "Family Room (L1)"    |
# | 206 | "Family Room (L1)"    |
# | 207 | "Family Room (L1)"    |
# | 208 | "Family Room (L1)"    |
# | 209 | "Family Room (L1)"    |
# | 210 | "Family Room (L1)"    |
# | 211 | "Family Room (L1)"    |
# | 212 | "Family Room (L1)"    |
# | 213 | "Family Room (L1)"    |
# | 214 | "Family Room (L1)"    |
# | 215 | "Family Room (L1)"    |
#
# | Row | description                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |-----|----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | 1   | "Let me tell you about Homestuck. What started as a text adventure-style web comic has spawned a world of mythology, fan work, community participation, and even an upcoming game. \r\n\r\nWhat is it about Homestuck that has resulted in such a huge following? Our experts will tell you all about the comic and the weird and wonderful universe it has spawned."                                                                                  |
# | 2   | "A look at what moments changed Dr Who and resonated through its’ fifty year history. Elements of the show that worked, why they worked, how do they resonate today."                                                                                                                                                                                                                                                                              |
# | 3   | "Writing often reflects the real world, but sometimes the real world isn't the best place to be. Sometimes, when faced with inequalities in the real world, writers will create books that push against that dominant narrative. How do they do it, and what does it look like?"                                                                                                                                                                   |
# | 4   | "So here's a cooking show like you wouldn't believe. The presenter is a cook, not a chef, so the recipes can actually be made. He brings a science bent to it, so you know WHY you need to do the things the recipe requires, plus a Food Anthropologist assists so you know the history of your food. Finally he brings a geek cred, quoting Monty Python, Indiana Jones and even the Exorcist. That's why this show is gosh darn it, GOOD EATS!" |
# | 5   | "There are lots of shows that didn't make it past their first or second season despite good premises for a variety of reasons. This doesn't make them bad shows. Our panellists discuss what died young, why it died young and why you should still watch it.\r\nPLEASE NOTE: \"FIREFLY\" is not going to be discussed here."                                                                                                                          |
# | 6   | "As the power of BlizElectronic Arctovision rose, more and more great developers squeezed out the sides. At the same time new distribution models appeared (STEAM, the \"bundles\", Desura and the like) allowed a new model to develop. Add in kickstarter and suddenly Indie Games are the place everyone wants to be be. Come hear about this fascinating phenomenon, including comments by members of local indie development teams."            |
# | 7   | "_Person of Interest_, the CBS crime procedural show, has a surprising number of SF fans. What makes this show so popular among SF fandom? Why is it so fun?"                                                                                                                                                                                                                                                                                      |
# | 8   | "Rather than focussing on the \"Latest and Greatest\" our panellists talk about what they like across all of their comics reading, from early strips to the modern age.\r\nEach panellists gets a tiny window to spruik their fave. Come along to pick up some great reading tips for comics you may not have previously read."                                                                                                                        |
# | 9   | "Before Chris Claremont came along, the X-Men had been cancelled. They were two dimensional and the villains were worse. A young up-n-coming comic writer was given the opportunity to \"try out\" on the back of a successful relaunch. Little did the Marvel management realise that within a few years, this unknown title by an unknown writer would allow them to dominate comics for years to come."                                           |
# | 10  | "Castle had a time-travel episode; Bones has dipped into the supernatural; White Collar deals regularly with conspiracies, both real and imagined. It seems that all throughout non-genre shows, genre themes keep popping up. Let's discuss some of our favourites, and why these themes are so appealing."                                                                                                                                       |
# | 11  | "What gets you hot outside the \"central\" fandom SF/F TV shows? Got a soft spot for \"White Collar\"? Like you some \"Leverage\"? \"Dexter\" does it for you? \"Breaking Bad\" is breaking good?"                                                                                                                                                                                                                                                           |
# ⋮
# | 204 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | 205 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | 206 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | 207 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | 208 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | 209 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | 210 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | 211 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | 212 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | 213 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | 214 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | 215 | NA                                                                                                                                                                                                                                                                                                                                                                                                                                                 |

# %%
@doc "Breaks up text, in to a list of words. It will split off the suffix and prefixes into seperate words if this causes the base word to be in the preffered words list" ->
function breakup_text(  text::String, 
    preferred_words::Set{String},
    suffixes = ["",",",";",".", "n't", "'s", "'ve", "!", "*", "...", "?", ":", ")", "\""],
    prefixes = ["","(", "\""])
    
    assert("" == suffixes[1])
    assert("" == prefixes[1])
    
    unpreferred_words = Array{String}(0)
    words = Array{String}(0)
    for field in split(text)
        found = false
        for pre in prefixes, suf in suffixes #The straight word is covered by the prefix and suffix ""
            if startswith(field,pre) && endswith(field,suf)
                word = field[1+length(pre):end-length(suf)]
                #println("***[$pre][$word][$suf]")
                if word in preferred_words
                    for part in [pre,word,suf]
                        if !isempty(part)
                            push!(words,part)
                        end
                    end
                    found = true
                    break
                end
            end
        end

        if !found #(ie else prefix loop not broken) so Not a prefferd word
            push!(words,field) #Put it on the word list anyway, it will be dealt with later
            push!(unpreferred_words,field) #but also note it as a problem
        end
        
    end
    words, unpreferred_words
end

function breakup_text(::DataArrays.NAtype, ::Set{AbstractString})
   NA, NA
end
# Out:
# breakup_text (generic function with 4 methods)

# %%
function get_total_embedding(embeddings::WordEmbeddingResolver, text::Union(String, NAtype))
    words = breakup_text(text, vocab_words(embeddings))[1]
    if words!==NA
        @>>words map(ww->embeddings[ww]) sum
    else
        NA
    end
end

@>> con[:description] map(desc->get_total_embedding(embeddings, desc))
# Out:
# 215-element DataArrays.DataArray{Any,1}:
#  [-16.6257,-0.928557,-11.488,-2.89466,13.6418,-6.10541,-1.9866,-21.7967,-9.14747,-13.6547  …  -7.69514,1.40531,23.0426,3.99472,14.7069,5.83933,2.90326,-15.8271,-1.52836,4.86375]
#  [-6.6499,-3.40094,-5.71016,-0.570224,4.08072,-3.86727,-2.49126,-10.4352,-5.02643,-6.69687  …  -1.62504,-2.24399,8.07558,0.445542,6.70399,1.96357,-0.549794,-5.38921,-0.308464,-0.338146]
#  [-16.8862,-4.36172,-9.70216,-1.72956,12.4142,-6.84941,-3.07433,-19.0553,-12.1232,-11.1566  …  -6.39796,-3.53723,16.4149,5.4134,14.1598,4.09036,0.0712288,-15.8708,1.75546,4.31328]
#  [-17.2586,-0.824012,-17.6213,-6.436,21.4533,-0.794672,-6.9247,-26.4433,-11.9014,-17.9525  …  -5.70992,-6.02505,34.8277,7.34487,15.7343,11.0217,5.7913,-17.8484,-5.76673,10.3581]
#  [-14.6064,-3.07196,-5.90239,-1.84735,11.2979,-4.89027,-4.14043,-22.376,-7.12063,-10.3965  …  -4.95223,-4.77935,14.3681,4.27299,11.4589,6.20743,3.10034,-16.5154,1.26115,6.89806]
#  [-11.8087,-3.45913,-11.683,2.84076,12.7031,-2.18148,-3.72303,-21.3258,-6.50539,-13.609  …  -6.04909,3.22497,18.7438,6.89945,14.6007,5.39016,3.54481,-20.7105,-3.30979,3.98235]
#  [-7.86822,-0.859824,-5.2342,-2.72325,4.0615,-3.87231,-0.211079,-9.81641,-5.86551,-5.79861  …  -1.42691,1.95495,10.8446,1.40041,3.94262,2.82435,-0.755001,-6.48456,-0.174177,-1.45767]
#  [-7.98437,-3.40495,-10.6944,-1.37439,12.6529,-4.42498,-0.480126,-19.1643,-4.45937,-10.3484  …  -2.80644,2.03462,14.2292,6.39043,9.60379,7.30805,3.66075,-14.0675,-4.75873,8.59639]
#  [-9.21193,-0.777858,-12.1547,0.901439,15.5568,-6.99282,-5.89562,-23.3393,-3.60517,-10.8348  …  -8.05353,5.1876,22.0276,8.3419,12.8661,8.22093,4.52794,-18.5771,-1.27845,-0.301696]
#  [-11.115,-0.340862,-2.54333,-2.25538,7.50946,-3.65549,1.22574,-14.4067,-7.04628,-10.9763  …  -6.63503,0.696654,15.1233,3.27961,8.42139,2.09929,1.80582,-12.4374,-0.901273,3.76025]
#  [-6.85205,-0.884511,-4.13045,-2.03341,5.68798,-4.34868,-2.87348,-11.2766,-2.1698,-4.1653  …  0.04053,-2.74837,9.66938,2.75827,5.86911,2.5812,3.23372,-9.22141,-2.62731,3.90271]
#  [-6.70182,-1.63974,-4.41927,-0.391704,4.58972,-2.10058,-1.37123,-9.35301,-2.97556,-5.86843  …  -0.605462,-1.18855,7.0424,3.93156,4.18359,2.67984,2.02,-8.25912,-2.74545,3.5259]
#  [-12.5481,-6.46486,-16.7477,-0.817121,13.1118,-5.72843,-3.69933,-21.0611,-7.57042,-13.5169  …  -5.53493,5.30719,20.2919,8.68769,15.5784,9.84418,7.73972,-18.8343,-6.61011,4.72729]
#  ⋮
#  NA
#  NA
#  NA
#  NA
#  NA
#  NA
#  NA
#  NA
#  NA
#  NA
#  NA
#  NA

# %%
if [1,2]!==NA
    println("jk")
end
# Out:
# jk
